# %%
from data import repository as rep
from eda import plotter as plt, helper as hlp

rep.bootstrap()

# %%
hlp.get_description('train', rep.test.columns)
# Out:
# Shape: (891, 10)
#              Type  Missing  Uniques      Mean       Std   Min     25%  \
# Pclass      int64        0        3   2.30864  0.836071     1       2
# Name       object        0      891      None      None  None    None
# Sex        object        0        2      None      None  None    None
# Age       float64      177       88   29.6991   14.5265  0.42  20.125
# SibSp       int64        0        7  0.523008   1.10274     0       0
# Parch       int64        0        7  0.381594  0.806057     0       0
# Ticket     object        0      681      None      None  None    None
# Fare      float64        0      248   32.2042   49.6934     0  7.9104
# Cabin      object      687      147      None      None  None    None
# Embarked   object        2        3      None      None  None    None
#
#               50%   75%      Max             High freq  \
# Pclass          3     3        3                     3
# Name         None  None     None  Davies, Mr. Alfred J
# ...

# %%
hlp.get_description('test', rep.test.columns)
# Out:
# Shape: (418, 10)
#              Type  Missing  Uniques      Mean       Std   Min     25%  \
# Pclass      int64        0        3   2.26555  0.841838     1       1
# Name       object        0      418      None      None  None    None
# Sex        object        0        2      None      None  None    None
# Age       float64       86       79   30.2726   14.1812  0.17      21
# SibSp       int64        0        7  0.447368   0.89676     0       0
# Parch       int64        0        8  0.392345  0.981429     0       0
# Ticket     object        0      363      None      None  None    None
# Fare      float64        1      169   35.6272   55.9076     0  7.8958
# Cabin      object      327       76      None      None  None    None
# Embarked   object        0        3      None      None  None    None
#
#               50%   75%      Max          High freq  \
# Pclass          3     3        3                  3
# Name         None  None     None  Lane, Mr. Patrick
# ...

# %%
plt.set_figure(figsize=(8, 6))
plt.target()

# %%
plt.count('Pclass')
plt.count('Sex')
plt.dist('Age')
plt.count('SibSp')
plt.count('Parch')
plt.dist('Fare')
plt.count('Embarked')
